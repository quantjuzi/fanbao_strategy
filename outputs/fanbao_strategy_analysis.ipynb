# %% [markdown]
# # ????????
# ## A???????????? ?? ??????
#
# > **??**?7?A??????? | **??**?????/????
# >
# > **????**?[github.com/quantjuzi/fanbao_strategy](https://github.com/quantjuzi/fanbao_strategy)
# >
# > **????**?2026-07-21
#
# ---

# %% [markdown]
# ## ????
#
# ?????A????????????????????????????????????
#
# ### ???
#
# | ?? | ?? |
# |---|---|
# | Python | ?????????????? |
# | Pandas / NumPy | ?????????????? |
# | Matplotlib | ???????????????? |
# | ?????? | A???????? |
# | Jupyter | ???????????? |
#
# ### ????
#
# ```
# fanbao_strategy/
#   daily_screen.py        # ?????????
#   scripts/               # ????
#   strategies/            # ????
#   backtest/              # ???? + ?????
#   trade_log.csv          # ??????
#   daily_notes/           # ????
#   reports/               # ????
#   ??/                   # ??????
# ```

# %% [markdown]
# ## ????
#
# ### ???????1 ? ??????
#
# **????**?????????????????? ? T+1???
#
# **?????**
# 1. T-2?T-3????????
# 2. T-1????
# 3. T-1???? > 15?
# 4. ???????M7/M14 > 1.05?
# 5. ????? > -3%?????
# 6. ????? > 1????? > ?????
#
# ### ?????????2 ? ????
#
# ??????????? + ????????????

# %% [markdown]
# ## ????
#
# ??????A????5509??????? 2026.04.12-2026.06.12
#
# ### ???????M7/M14 > 1.05?
#
# | ?? | ?? |
# |---|---|
# | ???? | 364 |
# | ?? | 51.1% |
# | ?????? | +1.12% |
#
# ### ????
#
# | ?? | ??? | ?? |
# |---|---|---|
# | 1.0 | 629 | 50.9% |
# | **1.05** | **364** | **51.1%** |
# | 1.1 | 131 | 51.1% |
#
# 1.05????????????????

# %% [markdown]
# ## ?????2026.06.17 ? ???
#
# | ?? | ?? |
# |---|---|
# | ???? | 50,000 |
# | ???? | 50,247 |
# | ???? | +0.49% |
# | ???? | 35 |
# | ?? | 54.3% |
# | ???? | +1.11% |
# | ??? | 1.44 |
# | ???? | 2.33 |
# | ???? | -32.05% |
#
# ### ????
# ![????](../reports/performance_chart.png)
#
# **?????**
# - 6?17-25??????????
# - 6?26?/30???????
# - 7?21?????????????
# - ??2.33????????

# %% [markdown]
# ## ????
#
# ### ??TOP5
# | ?? | ?? | ?? |
# |---|---|---|
# | 06-22 | ???? | +18.73% |
# | 07-01 | ???? | +14.74% |
# | 06-25 | ???? | +10.78% |
# | 07-01 | ???? | +10.71% |
# | 06-25 | ???? | +7.65% |
#
# ### ??TOP5
# | ?? | ?? | ?? |
# |---|---|---|
# | 07-21 | ??? | -17.60% |
# | 06-30 | ???? | -10.23% |
# | 06-26 | ???? | -9.50% |
# | 06-30 | ???? | -7.29% |
# | 06-22 | ???? | -6.18% |
#
# **??**????>1???>50%??????????????????/???

# %% [markdown]
# ## ?????
#
# - A?????API?????????
# - ??xgboost/lgbm????????
# - ????????????
# - ?????????/????
# - ???????????????
#
# ---
# > **??**????????????????
# > **GitHub**?[quantjuzi/fanbao_strategy](https://github.com/quantjuzi/fanbao_strategy)
